# %%
# Power P1 – Cross-modal fusion latency  
**Variable:** audiovisual ERP fusion window **< 50 ms**  
**Paradigm:** MEG/EEG multisensory oddball

# %%
import sys, numpy as np, matplotlib.pyplot as plt
sys.path.append('..')                    # ← path fix

from src.power_analysis import simulate_p1

np.random.seed(42)
lat = simulate_p1()
print(f"Mean fusion window = {lat.mean():.1f} ms  (criterion < 50 ms)")

plt.hist(lat, color='skyblue')
plt.axvline(50, color='r', lw=2)
plt.xlabel("Fusion latency (ms)"); plt.ylabel("Count")
plt.savefig("figure_P1_latency.png", dpi=300); plt.show()
# Out:
# Mean fusion window = 43.8 ms  (criterion < 50 ms)
